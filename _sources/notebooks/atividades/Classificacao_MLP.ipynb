# %% [markdown]
# ## Multi Layer Perceptron ( MLP )  __________________________________

# %% [markdown]
# Importar as bibliotecas

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import normalize
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score
import tensorflow as tf
from keras import utils

# %% [markdown]
# ### Carregar Base de Dados

# %%
data=pd.read_csv("../../data/databaseIris.csv")
data.sample(10)
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth          Species
# 66           5.6         3.0          4.5         1.5  Iris-versicolor
# 29           4.7         3.2          1.6         0.2      Iris-setosa
# 72           6.3         2.5          4.9         1.5  Iris-versicolor
# 2            4.7         3.2          1.3         0.2      Iris-setosa
# 43           5.0         3.5          1.6         0.6      Iris-setosa
# 105          7.6         3.0          6.6         2.1   Iris-virginica
# 81           5.5         2.4          3.7         1.0  Iris-versicolor
# 122          7.7         2.8          6.7         2.0   Iris-virginica
# 7            5.0         3.4          1.5         0.2      Iris-setosa
# 45           4.8         3.0          1.4         0.3      Iris-setosa

# %% [markdown]
# ###  Codificar as categorias

# %%
data.loc[data["Species"]=="Iris-setosa","Species"]=0
data.loc[data["Species"]=="Iris-versicolor","Species"]=1
data.loc[data["Species"]=="Iris-virginica","Species"]=2

data=data.iloc[np.random.permutation(len(data))]
print(data.sample(10))
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth Species
# 29           4.7         3.2          1.6         0.2       0
# 113          5.7         2.5          5.0         2.0       2
# 138          6.0         3.0          4.8         1.8       2
# 80           5.5         2.4          3.8         1.1       1
# 70           5.9         3.2          4.8         1.8       1
# 59           5.2         2.7          3.9         1.4       1
# 69           5.6         2.5          3.9         1.1       1
# 64           5.6         2.9          3.6         1.3       1
# 93           5.0         2.3          3.3         1.0       1
# 41           4.5         2.3          1.3         0.3       0

# %% [markdown]
# ### Separar dados descritivos das classes

# %%
X=data.iloc[:,:4].values
y=data.iloc[:,4].values

# %%
print("Shape of X",X.shape)
print("Shape of y",y.shape)
# Out:
# Shape of X (150, 4)
# Shape of y (150,)

# %% [markdown]
# ### Dividir dados para treinamento, validação e teste

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import normalize
import numpy as np

#Normalizar os dados
X_normalized = normalize(X,axis=0)

X_train_val,X_test,y_train_val,y_test=train_test_split(X_normalized,y,test_size=0.1,random_state=42)
X_train,X_val,y_train,y_val=train_test_split(X_train_val,y_train_val,test_size=0.1,random_state=42)

#Transformar os rótulos em categorias
num_classes=3
y_train=utils.to_categorical(y_train,num_classes)
y_val=utils.to_categorical(y_val,num_classes)
y_test=utils.to_categorical(y_test,num_classes)

# %% [markdown]
# ## Arquitetura do MLP

# %%
model = tf.keras.models.Sequential()

model.add(tf.keras.layers.Dense(16,input_dim=4,activation='relu'))
model.add(tf.keras.layers.Dense(64,activation='relu'))
model.add(tf.keras.layers.Dense(64,activation='relu'))

model.add(tf.keras.layers.Dense(3,activation='softmax'))

model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 16)             │            80 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         1,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 3)              │           195 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,523 (21.57 KB)
#  Trainable params: 5,523 (21.57 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Treinar a rede

# %%
class_weights = {
    0:1.0, #peso da classe 0
    1:1.0, #peso da classe 1
    2:1.0, #peso da classe 2
}

# %%
model.fit(X_train,y_train,validation_split=0.2,batch_size=16,epochs=50,verbose=1,class_weight=class_weights)
# Out:
# Epoch 1/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.5902 - loss: 1.0951 - val_accuracy: 0.5200 - val_loss: 1.0929
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6421 - loss: 1.0842 - val_accuracy: 0.4800 - val_loss: 1.0885
# Epoch 3/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5749 - loss: 1.0755 - val_accuracy: 0.5200 - val_loss: 1.0863
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5996 - loss: 1.0734 - val_accuracy: 0.5200 - val_loss: 1.0780
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6817 - loss: 1.0560 - val_accuracy: 0.5200 - val_loss: 1.0715
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7360 - loss: 1.0432 - val_accuracy: 0.5200 - val_loss: 1.0639
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6772 - loss: 1.0392 - val_accuracy: 0.5200 - val_loss: 1.0519
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7034 - loss: 1.0114 - val_accuracy: 0.5200 - val_loss: 1.0375
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6841 - loss: 0.9994 - val_accuracy: 0.5200 - val_loss: 1.0202
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7265 - loss: 0.9537 - val_accuracy: 0.5200 - val_loss: 1.0012
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6981 - loss: 0.9335 - val_accuracy: 0.5200 - val_loss: 0.9789
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7403 - loss: 0.8887 - val_accuracy: 0.5200 - val_loss: 0.9532
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7552 - loss: 0.8355 - val_accuracy: 0.5200 - val_loss: 0.9265
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7321 - loss: 0.8150 - val_accuracy: 0.5200 - val_loss: 0.8894
# Epoch 15/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7455 - loss: 0.7490 - val_accuracy: 0.5200 - val_loss: 0.8571
# Epoch 16/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7394 - loss: 0.7062 - val_accuracy: 0.5200 - val_loss: 0.8196
# Epoch 17/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7173 - loss: 0.6742 - val_accuracy: 0.5200 - val_loss: 0.7817
# Epoch 18/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7223 - loss: 0.6227 - val_accuracy: 0.5200 - val_loss: 0.7401
# Epoch 19/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7060 - loss: 0.5892 - val_accuracy: 0.5200 - val_loss: 0.6972
# Epoch 20/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6951 - loss: 0.5506 - val_accuracy: 0.5200 - val_loss: 0.6513
# Epoch 21/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7287 - loss: 0.5287 - val_accuracy: 0.5200 - val_loss: 0.6145
# Epoch 22/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8019 - loss: 0.4566 - val_accuracy: 0.5200 - val_loss: 0.5872
# Epoch 23/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8353 - loss: 0.4216 - val_accuracy: 0.6800 - val_loss: 0.5350
# Epoch 24/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9016 - loss: 0.3995 - val_accuracy: 0.6000 - val_loss: 0.5311
# Epoch 25/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8438 - loss: 0.3969 - val_accuracy: 0.7200 - val_loss: 0.4764
# Epoch 26/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9467 - loss: 0.3528 - val_accuracy: 0.8800 - val_loss: 0.4403
# Epoch 27/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9641 - loss: 0.3298 - val_accuracy: 0.8800 - val_loss: 0.4189
# Epoch 28/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9455 - loss: 0.2775 - val_accuracy: 0.8000 - val_loss: 0.4142
# Epoch 29/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9533 - loss: 0.3015 - val_accuracy: 0.9200 - val_loss: 0.3604
# Epoch 30/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9952 - loss: 0.2512 - val_accuracy: 0.9200 - val_loss: 0.3686
# Epoch 31/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9930 - loss: 0.2156 - val_accuracy: 0.9200 - val_loss: 0.3311
# Epoch 32/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.1969 - val_accuracy: 0.9200 - val_loss: 0.3096
# Epoch 33/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.2045 - val_accuracy: 0.9200 - val_loss: 0.2922
# Epoch 34/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.1669 - val_accuracy: 0.9200 - val_loss: 0.2710
# Epoch 35/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.1798 - val_accuracy: 0.9200 - val_loss: 0.2841
# Epoch 36/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.1685 - val_accuracy: 0.9200 - val_loss: 0.2574
# Epoch 37/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.1521 - val_accuracy: 0.9200 - val_loss: 0.2270
# Epoch 38/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.1361 - val_accuracy: 0.9200 - val_loss: 0.2527
# Epoch 39/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.1224 - val_accuracy: 0.9200 - val_loss: 0.2248
# Epoch 40/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.1218 - val_accuracy: 0.9200 - val_loss: 0.2051
# Epoch 41/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.1185 - val_accuracy: 0.9200 - val_loss: 0.2268
# Epoch 42/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.1126 - val_accuracy: 0.9600 - val_loss: 0.1744
# Epoch 43/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.1061 - val_accuracy: 0.9200 - val_loss: 0.2152
# Epoch 44/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0947 - val_accuracy: 0.9200 - val_loss: 0.1956
# Epoch 45/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0964 - val_accuracy: 0.9200 - val_loss: 0.1634
# Epoch 46/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0901 - val_accuracy: 0.9200 - val_loss: 0.1742
# Epoch 47/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0854 - val_accuracy: 0.9200 - val_loss: 0.2000
# Epoch 48/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0894 - val_accuracy: 0.9600 - val_loss: 0.1482
# Epoch 49/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0710 - val_accuracy: 0.9200 - val_loss: 0.1713
# Epoch 50/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0749 - val_accuracy: 0.9200 - val_loss: 0.1715

# %% [markdown]
# ### Testar

# %%
#Fazer previsoes nos dados de teste
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred,axis=1)

#Calcular a matriz de confusão
matriz_confusao=confusion_matrix(np.argmax(y_test,axis=1),y_pred_classes)

#Calcular a acurácia
acuracia=accuracy_score(np.argmax(y_test,axis=1),y_pred_classes)

#Calcular o score F1
f1=f1_score(np.argmax(y_test,axis=1),y_pred_classes,average='macro')

print("Matriz de confusão")
print(matriz_confusao)
print("Acuracia:")
print(acuracia)
print("Score F1")
print(f1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# Matriz de confusão
# [[5 0 0]
#  [0 7 1]
#  [0 0 2]]
# Acuracia:
# 0.9333333333333333
# Score F1
# 0.9111111111111111

# %%
model.layers[0].get_weights()[1]
# Out:
# array([ 0.02995397,  0.        ,  0.        ,  0.0130249 ,  0.        ,
#         0.14803235,  0.        , -0.00047829,  0.11024   ,  0.        ,
#         0.00806536,  0.03042303, -0.02368089,  0.06362233,  0.        ,
#         0.10174508], dtype=float32)
